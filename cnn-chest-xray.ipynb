# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import os
import pathlib
import PIL
import matplotlib.pyplot as plt
import seaborn as sb

# %%
train_path = pathlib.Path("../input/chest-xray-pneumonia/chest_xray/train")
val_path = pathlib.Path("../input/chest-xray-pneumonia/chest_xray/val")
test_path = pathlib.Path("../input/chest-xray-pneumonia/chest_xray/test")

# %%
image_count = len(list(train_path.glob("*/*.jpeg")))
image_count
# Out:
# 5216

# %%
normal_vis = list(train_path.glob("NORMAL/*.jpeg"))
plt.figure(figsize = (10, 10))

for i in range(25):
    plt.subplot(5, 5, i + 1)
    img = PIL.Image.open(str(normal_vis[i]))
    plt.imshow(img)
    plt.axis(False)
    
#del normal_vis

# %%
PIL.Image.open(str(normal_vis[-1]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=L size=1592x1272>

# %%
batch_size = 100
image_width = 128
image_height = 128
random_state = 100

# %%
train_data = tf.keras.preprocessing.image_dataset_from_directory(
                                                                train_path,
                                                                image_size = (image_height, image_width),
                                                                batch_size = batch_size
)

val_data = tf.keras.preprocessing.image_dataset_from_directory(
                                                                val_path,
                                                                image_size = (image_height, image_width),
                                                                batch_size = batch_size
)

test_data = tf.keras.preprocessing.image_dataset_from_directory(
                                                                test_path,
                                                                image_size = (image_height, image_width),
                                                                batch_size = batch_size
)
# Out:
# Found 5216 files belonging to 2 classes.
# 2022-06-30 13:12:27.742588: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-30 13:12:27.751181: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-30 13:12:27.751885: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-30 13:12:27.753935: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-06-30 13:12:27.754172: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-30 13:12:27.754878: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-30 13:12:27.755541: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-30 13:12:28.395456: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-30 13:12:28.396258: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-30 13:12:28.396982: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-30 13:12:28.397596: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15403 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Found 16 files belonging to 2 classes.
# Found 624 files belonging to 2 classes.

# %%
class_names = train_data.class_names
class_names
# Out:
# ['NORMAL', 'PNEUMONIA']

# %%
plt.figure(figsize = (10, 10))
for images, labels in train_data.take(1):
    for i in range(25):
        plt.subplot(5, 5, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(class_names[labels[i]])
        plt.axis(False)
# Out:
# 2022-06-30 13:12:40.285879: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)

# %%
data_augmentation = tf.keras.Sequential([
    tf.keras.layers.RandomFlip("horizontal_and_vertical"),
    tf.keras.layers.RandomRotation(0.2)
])

# %%
data_preprocessing_resnet = tf.keras.applications.resnet.preprocess_input

base_model_resnet = tf.keras.applications.resnet.ResNet50(
    input_shape = (image_height, image_width, 3),
    include_top = False,
    weights = "imagenet"
)

# %%
base_model_resnet.trainable = False

# %%
global_average_layer = tf.keras.layers.GlobalAveragePooling2D()
prediction_layer = tf.keras.layers.Dense(1, activation = "sigmoid")

# %%
inputs = tf.keras.Input((128, 128, 3))
x = data_augmentation(inputs)
x = data_preprocessing_resnet(x)
x = base_model_resnet(x, training = False)
x = global_average_layer(x)
x = tf.keras.layers.Dropout(0.2)(x)
outputs = prediction_layer(x)

# %%
model_resnet = tf.keras.Model(inputs = inputs, outputs = outputs)
optimizer = tf.keras.optimizers.Adam(learning_rate = 0.05)

# %%
model_resnet.compile(
                        optimizer = optimizer,
                        loss = tf.keras.losses.BinaryCrossentropy(from_logits = False),
                        metrics = ["accuracy"]
)

# %%
early_stopping = tf.keras.callbacks.EarlyStopping(monitor="val_loss", patience = 5)

# %%
history_resnet = model_resnet.fit(train_data, validation_data = val_data, batch_size = 100, epochs = 1000, callbacks=[early_stopping])
# Out:
# Epoch 1/1000
# 2022-06-30 13:14:09.578054: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8005
# 53/53 [==============================] - 31s 443ms/step - loss: 0.9552 - accuracy: 0.8976 - val_loss: 3.6008 - val_accuracy: 0.5625
# Epoch 2/1000
# 53/53 [==============================] - 25s 416ms/step - loss: 0.5763 - accuracy: 0.9181 - val_loss: 4.3475 - val_accuracy: 0.6875
# Epoch 3/1000
# 53/53 [==============================] - 26s 424ms/step - loss: 0.7195 - accuracy: 0.9256 - val_loss: 2.9146 - val_accuracy: 0.6875
# Epoch 4/1000
# 53/53 [==============================] - 26s 425ms/step - loss: 0.6167 - accuracy: 0.9350 - val_loss: 1.6121 - val_accuracy: 0.8125
# Epoch 5/1000
# 53/53 [==============================] - 26s 427ms/step - loss: 0.6193 - accuracy: 0.9308 - val_loss: 1.5720 - val_accuracy: 0.8125
# Epoch 6/1000
# 53/53 [==============================] - 26s 421ms/step - loss: 0.7108 - accuracy: 0.9277 - val_loss: 0.7940 - val_accuracy: 0.8750
# Epoch 7/1000
# 53/53 [==============================] - 26s 430ms/step - loss: 0.5666 - accuracy: 0.9367 - val_loss: 1.2634 - val_accuracy: 0.8125
# Epoch 8/1000
# 53/53 [==============================] - 26s 430ms/step - loss: 0.7004 - accuracy: 0.9266 - val_loss: 3.9008 - val_accuracy: 0.6250
# Epoch 9/1000
# 53/53 [==============================] - 26s 421ms/step - loss: 0.8136 - accuracy: 0.9331 - val_loss: 1.0174 - val_accuracy: 0.8750
# Epoch 10/1000
# 53/53 [==============================] - 25s 410ms/step - loss: 0.7398 - accuracy: 0.9333 - val_loss: 15.0292 - val_accuracy: 0.5000
# Epoch 11/1000
# 53/53 [==============================] - 26s 423ms/step - loss: 1.1573 - accuracy: 0.9227 - val_loss: 0.7865 - val_accuracy: 0.9375
# Epoch 12/1000
# 53/53 [==============================] - 26s 429ms/step - loss: 0.8146 - accuracy: 0.9400 - val_loss: 8.1121 - val_accuracy: 0.5625
# Epoch 13/1000
# 53/53 [==============================] - 26s 421ms/step - loss: 1.0422 - accuracy: 0.9298 - val_loss: 1.5163 - val_accuracy: 0.8750
# Epoch 14/1000
# 53/53 [==============================] - 25s 416ms/step - loss: 0.7730 - accuracy: 0.9429 - val_loss: 1.4351 - val_accuracy: 0.8750
# Epoch 15/1000
# 53/53 [==============================] - 26s 407ms/step - loss: 0.6432 - accuracy: 0.9465 - val_loss: 0.3003 - val_accuracy: 0.9375
# Epoch 16/1000
# 53/53 [==============================] - 26s 425ms/step - loss: 0.8604 - accuracy: 0.9314 - val_loss: 3.1118 - val_accuracy: 0.6250
# Epoch 17/1000
# 53/53 [==============================] - 26s 413ms/step - loss: 1.1547 - accuracy: 0.9260 - val_loss: 0.0034 - val_accuracy: 1.0000
# Epoch 18/1000
# 53/53 [==============================] - 26s 430ms/step - loss: 1.0364 - accuracy: 0.9294 - val_loss: 0.6780 - val_accuracy: 0.8750
# Epoch 19/1000
# 53/53 [==============================] - 26s 427ms/step - loss: 0.7800 - accuracy: 0.9444 - val_loss: 1.3521 - val_accuracy: 0.8750
# Epoch 20/1000
# 53/53 [==============================] - 26s 428ms/step - loss: 0.7430 - accuracy: 0.9477 - val_loss: 2.7765e-05 - val_accuracy: 1.0000
# Epoch 21/1000
# 53/53 [==============================] - 25s 414ms/step - loss: 1.0945 - accuracy: 0.9298 - val_loss: 1.5144 - val_accuracy: 0.8750
# Epoch 22/1000
# 53/53 [==============================] - 26s 428ms/step - loss: 0.7816 - accuracy: 0.9448 - val_loss: 1.2414 - val_accuracy: 0.8750
# Epoch 23/1000
# 53/53 [==============================] - 26s 423ms/step - loss: 0.7687 - accuracy: 0.9459 - val_loss: 1.6670 - val_accuracy: 0.8125
# Epoch 24/1000
# 53/53 [==============================] - 26s 427ms/step - loss: 0.7460 - accuracy: 0.9423 - val_loss: 1.1141 - val_accuracy: 0.8750
# Epoch 25/1000
# 53/53 [==============================] - 25s 408ms/step - loss: 0.9919 - accuracy: 0.9354 - val_loss: 1.0336 - val_accuracy: 0.8125

# %%
#PLotting the graph between epochs loss for loss and val_loss

sb.lineplot(x = range(len(history_resnet.history["loss"])), y = history_resnet.history["loss"], label = "Training")
sb.lineplot(x = range(len(history_resnet.history["loss"])), y = history_resnet.history["val_loss"], label = "Validation")
plt.ylabel("Loss")
plt.xlabel("Epochs")
plt.legend()

# %%
#PLotting the graph between epochs loss for accuracy and val_accuracy

sb.lineplot(x = range(len(history_resnet.history["loss"])), y = history_resnet.history["accuracy"], label = "Training")
sb.lineplot(x = range(len(history_resnet.history["loss"])), y = history_resnet.history["val_accuracy"], label = "Validation")
plt.ylabel("Loss")
plt.xlabel("Epochs")
plt.legend(loc = "lower right")

# %%
# Evaluate the model
result_resnet = model_resnet.evaluate(test_data)
print(f"Loss: {result_resnet[0]}")
print(f"Accuracy: {result_resnet[1] * 100}")
# Out:
# 7/7 [==============================] - 4s 77ms/step - loss: 3.2120 - accuracy: 0.8349
# Loss: 3.2119624614715576
# Accuracy: 83.49359035491943
